# %%
import pandas as Ht_De_Pn
Ht_De_Ptn = Ht_De_Pn.read_csv('heart_disease_uci.csv')
Ht_De_Ptn.shape
# Out:
# (920, 16)

# %%
Ht_De_Ptn.head(10)
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# 5   6   56    Male  Cleveland  atypical angina     120.0  236.0  False
# 6   7   62  Female  Cleveland     asymptomatic     140.0  268.0  False
# 7   8   57  Female  Cleveland     asymptomatic     120.0  354.0  False
# 8   9   63    Male  Cleveland     asymptomatic     130.0  254.0  False
# 9  10   53    Male  Cleveland     asymptomatic     140.0  203.0   True
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# ...

# %%
Ht_De_Ptn.tail(10)
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 910  911   51  Female  VA Long Beach     asymptomatic     114.0  258.0   True
# 911  912   62    Male  VA Long Beach     asymptomatic     160.0  254.0   True
# 912  913   53    Male  VA Long Beach     asymptomatic     144.0  300.0   True
# 913  914   62    Male  VA Long Beach     asymptomatic     158.0  170.0  False
# 914  915   46    Male  VA Long Beach     asymptomatic     134.0  310.0  False
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak      slope  ca          thal  \
# ...

# %%
Ht_De_Ptn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
Ht_De_Ptn.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
Ht_De_Ptn.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %%
Ht_De_Ptn['num'].value_counts()
# Out:
# 0    411
# 1    265
# 2    109
# 3    107
# 4     28
# Name: num, dtype: int64

# %%
Ht_De_Ptn['num'] = Ht_De_Ptn['num'].replace({1: 1, 2: 1, 3: 1, 4: 1})
Ht_De_Ptn['num'].value_counts()
# Out:
# 1    509
# 0    411
# Name: num, dtype: int64

# %%
print("NaN data :",Ht_De_Ptn.isnull().values.sum())

### dropping nan values
Ht_De_Ptn.dropna(inplace=True)
print("shape after removing nan data :",Ht_De_Ptn.shape)
# Out:
# NaN data : 1759
# shape after removing nan data : (299, 16)

# %%
duplicates = Ht_De_Ptn[Ht_De_Ptn.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [id, age, sex, dataset, cp, trestbps, chol, fbs, restecg, thalch, exang, oldpeak, slope, ca, thal, num]
# Index: []

# %%
Ht_De_Ptn=Ht_De_Ptn.drop_duplicates()

# %%
Ht_De_Ptn.shape
# Out:
# (299, 16)

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as Ht_De_Matplt
import seaborn as Ht_De_sabn
import warnings as Ht_De_wngs
Ht_De_wngs.filterwarnings('ignore')

# %%
Ht_De_sabn.countplot(x ='num', data = Ht_De_Ptn, palette="viridis")
Ht_De_Matplt.title('Heart Disease Prediction')
Ht_De_Matplt.show()

# %%
Ht_De_sabn.lineplot(x="trestbps", y="num", data=Ht_De_Ptn)
Ht_De_Matplt.title('columns "trestbps" vs "target"')
Ht_De_Matplt.show()

# %% [markdown]
# # Encoding the data

# %%
from sklearn import preprocessing as Ht_De_Ptn_Pre
Ht_De_Ptn_LE = Ht_De_Ptn_Pre.LabelEncoder()
Ht_De_Ptn_Pre = Ht_De_Ptn.apply(Ht_De_Ptn_LE.fit_transform)
Ht_De_Ptn_Pre
# Out:
#       id  age  sex  dataset  cp  trestbps  chol  fbs  restecg  thalch  exang  \
# 0      0   29    1        0   3        31    65    1        0      50      0
# 1      1   33    1        0   0        40   112    0        0      11      1
# 2      2   33    1        0   0        14    61    0        0      30      1
# 3      3    3    1        0   2        22    81    0        1      85      0
# 4      4    7    0        0   1        22    36    0        0      72      0
# ..   ...  ...  ...      ...  ..       ...   ...  ...      ...     ...    ...
# 299  294   34    1        0   0        30    27    1        1      41      0
# 300  295   23    1        0   0        22     2    0        1      17      1
# 301  296   23    0        0   1        22    68    0        0      74      0
# 508  297   13    1        1   0        34    58    0        1       6      1
# 748  298   22    1        2   0        14     0    0        1      21      1
#
#      oldpeak  slope  ca  thal  num
# ...

# %%
Ht_De_Ptn_Pre.to_csv("pre_proc_heart_disease_dataset2.csv", index=False)
Ht_De_Ptn_Pre.shape
# Out:
# (299, 16)
